# %%
import duckdb
import pandas as pd

server="oss.resilientservice.mooo.com"
bucket= "resilentpublic"
#bucket= "test"
s3_setup="""CREATE OR REPLACE SECRET s3_credentials(
    TYPE s3,

    ENDPOINT 'oss.resilientservice.mooo.com',
    URL_STYLE 'path'
);
"""
con = duckdb.connect()
con.execute(s3_setup)

# %%
hs2s_base="latest/tijuana/sd_apcd_air/h2s"
hs2name_pattern="*.parquet"
hs2_files=f"s3://{bucket}/{hs2s_base}/{hs2name_pattern}"

hs2_data2=con.read_parquet(hs2_files).df()
hs2_data2
# Out:
#            SiteName   Latitude   Longitude      AgencyName  \
# 0        SAN YSIDRO  32.552794 -117.047286  San Diego APCD
# 1        SAN YSIDRO  32.552794 -117.047286  San Diego APCD
# 2        SAN YSIDRO  32.552794 -117.047286  San Diego APCD
# 3        SAN YSIDRO  32.552794 -117.047286  San Diego APCD
# 4        SAN YSIDRO  32.552794 -117.047286  San Diego APCD
# ...             ...        ...         ...             ...
# 11811  IB CIVIC CTR  32.576139 -117.115361  San Diego APCD
# 11812  IB CIVIC CTR  32.576139 -117.115361  San Diego APCD
# 11813  IB CIVIC CTR  32.576139 -117.115361  San Diego APCD
# 11814  IB CIVIC CTR  32.576139 -117.115361  San Diego APCD
# 11815  IB CIVIC CTR  32.576139 -117.115361  San Diego APCD
#
#                           LongName   Parameter     Site Name  \
# 0                       San Ysidro  07 H2S PPB    SAN YSIDRO
# 1                       San Ysidro  07 H2S PPB    SAN YSIDRO
# 2                       San Ysidro  07 H2S PPB    SAN YSIDRO
# 3                       San Ysidro  07 H2S PPB    SAN YSIDRO
# 4                       San Ysidro  07 H2S PPB    SAN YSIDRO
# ...                            ...         ...           ...
# 11811  Imperial Beach Civic Center  07 H2S PPB  IB CIVIC CTR
# 11812  Imperial Beach Civic Center  07 H2S PPB  IB CIVIC CTR
# 11813  Imperial Beach Civic Center  07 H2S PPB  IB CIVIC CTR
# 11814  Imperial Beach Civic Center  07 H2S PPB  IB CIVIC CTR
# 11815  Imperial Beach Civic Center  07 H2S PPB  IB CIVIC CTR
#
#                   Date with time  Result Qualifier Original Value  Icons  \
# 0      2023-11-20T00:00:00-08:00     3.3                      3.3  place
# 1      2023-11-20T01:00:00-08:00     1.0                      1.0  place
# 2      2023-11-20T02:00:00-08:00     0.1                       .1  place
# 3      2023-11-20T03:00:00-08:00     0.0                       .0  place
# 4      2023-11-20T04:00:00-08:00     0.0                       .0  place
# ...                          ...     ...       ...            ...    ...
# 11811  2024-12-30T19:00:00-08:00    17.8                     17.8  place
# 11812  2024-12-30T20:00:00-08:00    16.1                     16.1  place
# 11813  2024-12-30T21:00:00-08:00     9.3                      9.3  place
# 11814  2024-12-30T22:00:00-08:00     5.0                      5.0  place
# 11815  2024-12-30T23:00:00-08:00     1.6                      1.6  place
#
#        aggregation_year              date_processed   level
# 0                  2023  2025-11-25T02:37:57.931181   green
# 1                  2023  2025-11-25T02:37:57.931181   green
# 2                  2023  2025-11-25T02:37:57.931181   green
# 3                  2023  2025-11-25T02:37:57.931181   green
# 4                  2023  2025-11-25T02:37:57.931181   green
# ...                 ...                         ...     ...
# 11811              2024  2025-11-25T02:37:40.288369  yellow
# 11812              2024  2025-11-25T02:37:40.288369  yellow
# 11813              2024  2025-11-25T02:37:40.288369  yellow
# 11814              2024  2025-11-25T02:37:40.288369  yellow
# 11815              2024  2025-11-25T02:37:40.288369   green
#
# [11816 rows x 15 columns]

# %%
sf_base="latest/tijuana/streamflow/boundary_cms"
sf_name_pattern="*.parquet"
sf_files=f"s3://{bucket}/{sf_base}/{sf_name_pattern}"

sf_data=con.read_parquet(sf_files).df()
sf_data
# Out:
#       End of Interval (UTC-08:00)  Average (m^3/s)  \
# 0             2020-01-01 01:00:00             4.98
# 1             2020-01-01 02:00:00             4.68
# 2             2020-01-01 03:00:00             4.57
# 3             2020-01-01 04:00:00             4.32
# 4             2020-01-01 05:00:00             4.15
# ...                           ...              ...
# 43723         2024-12-30 20:00:00             1.50
# 43724         2024-12-30 21:00:00             1.74
# 43725         2024-12-30 22:00:00             1.50
# 43726         2024-12-30 23:00:00             1.56
# 43727         2024-12-31 00:00:00             1.57
#
#       Start of Interval (UTC-08:00)
# 0               2020-01-01 00:00:00
# 1               2020-01-01 01:00:00
# 2               2020-01-01 02:00:00
# 3               2020-01-01 03:00:00
# 4               2020-01-01 04:00:00
# ...                             ...
# 43723           2024-12-30 19:00:00
# 43724           2024-12-30 20:00:00
# 43725           2024-12-30 21:00:00
# 43726           2024-12-30 22:00:00
# 43727           2024-12-30 23:00:00
#
# [43728 rows x 3 columns]
